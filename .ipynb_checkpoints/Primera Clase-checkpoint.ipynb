# %% [markdown]
# ## Mi primer programa
# # Angelica Paredes
# ### Introduccion a la Programacion con Python
# *Primer **Programa** en Python*
# > Nuestro Primer Hola Mundo

# %%
#Esta linea va a ser la primera que vamos a imprimir
print("Hola Mundo")
print(4)
print(3.1416)
print(True)

#Variables
nombre = "Angelica"
print(nombre)
# Out:
# Hola Mundo
# 4
# 3.1416
# True
# Angelica

# %% [markdown]
# # Clase 2
# Sintaxis Basica

# %%
"""
Nombre: Angelica Paredes
Programa del algoritmo que tienen, en un dia desde levantarse hasta acostarse
Programa mediante codigo ascii, para realizar una forma,objeto,animal,figura segun su creatividad
"""

#Define una variable llamada estudiante
estudiante = "Angelica"
#Imprime un Hola mas a la variable estudiante
print("Hola",estudiante)
#Salto de linea
print("Hola \nestimados estudiantes")
#Tabulacion
print("Menu:\tHamburguesa")
#Espacios literales
print("-Menu:    Pizza    -")

print("====================")
print(" Zona De Parqueadero ")
print("|Placa:   PGB-6869 |",
      "\n|*Hora Llegada: 19:22 |",
      "\n|*Hora Salida: 20:00|")
print("--------------------------")
print("             Subtotal:1.00")
print("--------------------------")
print("                  iva:0.15")
print("--------------------------")
print("                total:1.15")
# Out:
# Hola Angelica
# Hola
# estimados estudiantes
# Menu:	Hamburguesa
# -Menu:    Pizza    -
# ...
#  Zona De Parqueadero
# |Placa:   PGB-6869 |
# |*Hora Llegada: 19:22 |
# |*Hora Salida: 20:00|
# --------------------------
#              Subtotal:1.00
# --------------------------
#                   iva:0.15
# --------------------------
#                 total:1.15

# %%
#Algoritmo: Mi rutina diaria
print("1. Me levanto de la cama al sonar mi alarma.")
print("2. Me lavo la cara y me cepillo los dientes.")
print("3. Hago mi desayuno y almuerzo.")
print("4. Alisto el desayuno y almuerzo en la lonchera.")
print("5. Me visto con la ropa adecuada para el trabajo.")
print("6. Reviso mi bolso que este mis llaves y todo lo necesario.")
print("7. Cierro bien las puertas antes de salir.")
print("8. Camino hacia mi trabajo.")
print("9. Llego a mi trabajo recibo el turno para iniciar mi jornada.")
print("10. Desayuno e inicio con mis actividades durante la jornada.")
print("11. Tomo mis 40 minutos de almurzo.")
print("12. Continuo con mis labores hasta terminar mi jornada.")
print("13. Entrego mi turno y me retiro de mi trabajo.")
print("14. Regreso caminando a mi casa.")
print("15. Asisto a mis clases hasta las 21:30.")
print("16. Realizo mi aseo personal antes de dormir.")
print("17. Me acuesto a descansar.")
# Out:
# 1. Me levanto de la cama al sonar mi alarma.
# 2. Me lavo la cara y me cepillo los dientes.
# 3. Hago mi desayuno y almuerzo.
# 4. Alisto el desayuno y almuerzo en la lonchera.
# 5. Me visto con la ropa adecuada para el trabajo.
# 6. Reviso mi bolso que este mis llaves y todo lo necesario.
# 7. Cierro bien las puertas antes de salir.
# 8. Camino hacia mi trabajo.
# 9. Llego a mi trabajo recibo el turno para iniciar mi jornada.
# 10. Desayuno e inicio con mis actividades durante la jornada.
# 11. Tomo mis 40 minutos de almurzo.
# 12. Continuo con mis labores hasta terminar mi jornada.
# 13. Entrego mi turno y me retiro de mi trabajo.
# 14. Regreso caminando a mi casa.
# 15. Asisto a mis clases hasta las 21:30.
# 16. Realizo mi aseo personal antes de dormir.
# 17. Me acuesto a descansar.

# %%
print("  / \\__")
print(" (    @\\____")
print(" /         O")
print(" /   (_____/")
print(" / ____/  U")
# Out:
#   / \__
#  (    @\____
#  /         O
#  /   (_____/
#  / ____/  U
